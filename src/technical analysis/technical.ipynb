# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
filepath = '/content/timeseriesdata.csv'
df = pd.read_csv(filepath)
df
# Out:
#       Quarter  hdbrpi  ...  overall unemployment          sti
# 0    1990 1Q     24.3  ...                 31600  1458.400000
# 1    1990 2Q     24.4  ...                 31600  1527.000000
# 2    1990 3Q     25.0  ...                 31600  1098.700000
# 3    1990 4Q     24.7  ...                 31600  1154.800000
# 4    1991 1Q     24.9  ...                 31600  1490.800000
# ..        ...     ...  ...                   ...          ...
# 91   2012 4Q    146.7  ...                 63500  3167.080078
# 92   2013 1Q    148.6  ...                 65700  3308.100098
# 93   2013 2Q    149.4  ...                 67900  3150.439941
# 94   2013 3Q    148.1  ...                 63300  3167.870117
# 95   2013 4Q    145.8  ...                 66000  3167.429932
#
# [96 rows x 10 columns]

# %%
def todatetime(row):
    row['Quarter'] = row['Quarter'].replace(' 1Q', '-03')
    row['Quarter'] = row['Quarter'].replace(' 2Q', '-06')
    row['Quarter'] = row['Quarter'].replace(' 3Q', '-09')
    row['Quarter'] = row['Quarter'].replace(' 4Q', '-12')
    
    return row

df1 = df.apply(todatetime, axis='columns')
df1['Quarter'] = pd.to_datetime(df1['Quarter'], infer_datetime_format = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Quarter               96 non-null     datetime64[ns]
#  1   hdbrpi                96 non-null     float64
#  2   labour-cost           96 non-null     float64
#  3   gdp                   96 non-null     object
#  4   population            96 non-null     object
#  5   cpi                   96 non-null     float64
#  6   exchange-rate         96 non-null     float64
#  7   consumer-spending     96 non-null     float64
#  8   overall unemployment  96 non-null     int64
#  9   sti                   96 non-null     float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(2)
# memory usage: 7.6+ KB

# %%
def tofloat(row):
    row['gdp'] = row['gdp'].replace(',', '')
    row['population'] = row['population'].replace(',', '')
    return row

df2 = df1.apply(tofloat, axis='columns')
df2['gdp'] = df2['gdp'].astype(float)
df2['population'] = df2['population'].astype(float)
df2['overall unemployment'] = df2['overall unemployment'].astype(float)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Quarter               96 non-null     datetime64[ns]
#  1   hdbrpi                96 non-null     float64
#  2   labour-cost           96 non-null     float64
#  3   gdp                   96 non-null     float64
#  4   population            96 non-null     float64
#  5   cpi                   96 non-null     float64
#  6   exchange-rate         96 non-null     float64
#  7   consumer-spending     96 non-null     float64
#  8   overall unemployment  96 non-null     float64
#  9   sti                   96 non-null     float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 7.6 KB

# %%
df3 = df2.drop(columns = 'Quarter')
df3
# Out:
#     hdbrpi  labour-cost  ...  overall unemployment          sti
# 0     24.3         74.7  ...               31600.0  1458.400000
# 1     24.4         70.5  ...               31600.0  1527.000000
# 2     25.0         73.8  ...               31600.0  1098.700000
# 3     24.7         84.9  ...               31600.0  1154.800000
# 4     24.9         80.5  ...               31600.0  1490.800000
# ..     ...          ...  ...                   ...          ...
# 91   146.7         98.3  ...               63500.0  3167.080078
# 92   148.6        101.0  ...               65700.0  3308.100098
# 93   149.4         88.5  ...               67900.0  3150.439941
# 94   148.1         89.3  ...               63300.0  3167.870117
# 95   145.8         99.7  ...               66000.0  3167.429932
#
# [96 rows x 9 columns]

# %%
df4 = df3.hdbrpi
df4.shape
# Out:
# (96,)

# %%
data = df4.to_numpy()
data.shape
# Out:
# (96,)

# %%
num_features = 1
data = data.reshape((len(data), num_features))
data.shape
# Out:
# (96, 1)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(data, data, test_size=0.2, random_state=0, shuffle=False)

# %%
win_length = 6
print(Xtrain.shape)
print(Xtest.shape)
# Out:
# (76, 1)
# (20, 1)

# %%
train_generator = TimeseriesGenerator(Xtrain, Ytrain, length=win_length, sampling_rate=1, batch_size=96)
test_generator = TimeseriesGenerator(Xtest, Ytest, length=win_length, sampling_rate=1, batch_size=96)

# %%
X_train = train_generator[0][0]
Y_train = train_generator[0][1]
X_test = test_generator[0][0]
Y_test = test_generator[0][1]
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (70, 6, 1)
# (70, 1)
# (14, 6, 1)
# (14, 1)

# %%
print(len(X_train))
# Out:
# 70

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(16, activation='relu', input_shape=(win_length, num_features), return_sequences=False))
#model.add(tf.keras.layers.LSTM(10, activation='relu', return_sequences=True))
#model.add(tf.keras.layers.LSTM(16, activation='relu', return_sequences=True))
#model.add(tf.keras.layers.LSTM(10, activation='relu', return_sequences=True))
#model.add(tf.keras.layers.BatchNormalization())
#model.add(tf.keras.layers.LSTM(6, activation='relu', return_sequences=False))
model.add(tf.keras.layers.Dense(1))

# %%
model.compile(loss=tf.losses.MeanSquaredError(), optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=[tf.metrics.MeanAbsoluteError()])
history = model.fit(X_train, Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=6)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 1s 29ms/step - loss: 1972.2730 - mean_absolute_error: 39.9418 - val_loss: 2756.7827 - val_mean_absolute_error: 52.4188
# Epoch 2/200
# 12/12 [==============================] - 0s 6ms/step - loss: 317.8132 - mean_absolute_error: 14.2539 - val_loss: 440.7782 - val_mean_absolute_error: 20.8923
# Epoch 3/200
# 12/12 [==============================] - 0s 7ms/step - loss: 69.9804 - mean_absolute_error: 6.5035 - val_loss: 42.5474 - val_mean_absolute_error: 6.0676
# Epoch 4/200
# 12/12 [==============================] - 0s 7ms/step - loss: 53.5407 - mean_absolute_error: 5.9125 - val_loss: 52.5830 - val_mean_absolute_error: 6.8952
# Epoch 5/200
# 12/12 [==============================] - 0s 7ms/step - loss: 49.0651 - mean_absolute_error: 5.4069 - val_loss: 10.7187 - val_mean_absolute_error: 2.4924
# Epoch 6/200
# 12/12 [==============================] - 0s 7ms/step - loss: 53.8094 - mean_absolute_error: 5.2926 - val_loss: 11.9534 - val_mean_absolute_error: 2.4126
# Epoch 7/200
# 12/12 [==============================] - 0s 7ms/step - loss: 29.0628 - mean_absolute_error: 4.4571 - val_loss: 15.8740 - val_mean_absolute_error: 3.6075
# Epoch 8/200
# 12/12 [==============================] - 0s 7ms/step - loss: 28.0592 - mean_absolute_error: 4.2343 - val_loss: 24.8945 - val_mean_absolute_error: 4.1770
# Epoch 9/200
# 12/12 [==============================] - 0s 7ms/step - loss: 30.6850 - mean_absolute_error: 4.1052 - val_loss: 36.9919 - val_mean_absolute_error: 4.8981
# Epoch 10/200
# 12/12 [==============================] - 0s 7ms/step - loss: 39.5310 - mean_absolute_error: 4.7844 - val_loss: 47.5183 - val_mean_absolute_error: 5.9690
# Epoch 11/200
# 12/12 [==============================] - 0s 7ms/step - loss: 26.9522 - mean_absolute_error: 4.2631 - val_loss: 322.3517 - val_mean_absolute_error: 17.7647
# Epoch 12/200
# 12/12 [==============================] - 0s 8ms/step - loss: 48.1411 - mean_absolute_error: 5.4440 - val_loss: 42.7624 - val_mean_absolute_error: 6.0244
# Epoch 13/200
# 12/12 [==============================] - 0s 7ms/step - loss: 27.0453 - mean_absolute_error: 4.0032 - val_loss: 19.2455 - val_mean_absolute_error: 3.3302
# Epoch 14/200
# 12/12 [==============================] - 0s 7ms/step - loss: 20.0166 - mean_absolute_error: 3.5475 - val_loss: 34.5664 - val_mean_absolute_error: 4.7868
# Epoch 15/200
# 12/12 [==============================] - 0s 7ms/step - loss: 12.9451 - mean_absolute_error: 2.8002 - val_loss: 458.2369 - val_mean_absolute_error: 20.8024
# Epoch 16/200
# 12/12 [==============================] - 0s 8ms/step - loss: 16.6339 - mean_absolute_error: 3.2655 - val_loss: 1395.8685 - val_mean_absolute_error: 34.9142
# Epoch 17/200
# 12/12 [==============================] - 0s 8ms/step - loss: 13.2297 - mean_absolute_error: 2.7535 - val_loss: 190.4333 - val_mean_absolute_error: 11.9144
# Epoch 18/200
# 12/12 [==============================] - 0s 7ms/step - loss: 17.1680 - mean_absolute_error: 3.0612 - val_loss: 438.3610 - val_mean_absolute_error: 18.2010
# Epoch 19/200
# 12/12 [==============================] - 0s 7ms/step - loss: 18.1439 - mean_absolute_error: 3.5923 - val_loss: 156.6127 - val_mean_absolute_error: 12.0013
# Epoch 20/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.9657 - mean_absolute_error: 2.7137 - val_loss: 74.3746 - val_mean_absolute_error: 7.0786
# Epoch 21/200
# 12/12 [==============================] - 0s 7ms/step - loss: 20.8656 - mean_absolute_error: 3.8561 - val_loss: 840.6935 - val_mean_absolute_error: 27.5161
# Epoch 22/200
# 12/12 [==============================] - 0s 7ms/step - loss: 10.0884 - mean_absolute_error: 2.6128 - val_loss: 756.8927 - val_mean_absolute_error: 25.1610
# Epoch 23/200
# 12/12 [==============================] - 0s 8ms/step - loss: 13.4709 - mean_absolute_error: 2.7363 - val_loss: 631.4255 - val_mean_absolute_error: 22.5869
# Epoch 24/200
# 12/12 [==============================] - 0s 8ms/step - loss: 11.0889 - mean_absolute_error: 2.6722 - val_loss: 949.8667 - val_mean_absolute_error: 28.2715
# Epoch 25/200
# 12/12 [==============================] - 0s 8ms/step - loss: 5.5787 - mean_absolute_error: 1.7961 - val_loss: 960.9891 - val_mean_absolute_error: 28.4709
# Epoch 26/200
# 12/12 [==============================] - 0s 7ms/step - loss: 10.1205 - mean_absolute_error: 2.4786 - val_loss: 457.5283 - val_mean_absolute_error: 18.0005
# Epoch 27/200
# 12/12 [==============================] - 0s 8ms/step - loss: 10.8850 - mean_absolute_error: 2.6399 - val_loss: 1988.2213 - val_mean_absolute_error: 43.7391
# Epoch 28/200
# 12/12 [==============================] - 0s 7ms/step - loss: 14.6562 - mean_absolute_error: 2.6988 - val_loss: 835.7916 - val_mean_absolute_error: 27.8023
# Epoch 29/200
# 12/12 [==============================] - 0s 8ms/step - loss: 10.0149 - mean_absolute_error: 2.6693 - val_loss: 1337.1498 - val_mean_absolute_error: 35.1830
# Epoch 30/200
# 12/12 [==============================] - 0s 8ms/step - loss: 11.5038 - mean_absolute_error: 2.6465 - val_loss: 1300.3168 - val_mean_absolute_error: 34.9916
# Epoch 31/200
# 12/12 [==============================] - 0s 8ms/step - loss: 12.4461 - mean_absolute_error: 2.8022 - val_loss: 1691.8070 - val_mean_absolute_error: 39.9618
# Epoch 32/200
# 12/12 [==============================] - 0s 8ms/step - loss: 7.9269 - mean_absolute_error: 2.2588 - val_loss: 2112.3464 - val_mean_absolute_error: 45.5335
# Epoch 33/200
# 12/12 [==============================] - 0s 8ms/step - loss: 23.7536 - mean_absolute_error: 3.8348 - val_loss: 1701.5223 - val_mean_absolute_error: 40.8987
# Epoch 34/200
# 12/12 [==============================] - 0s 7ms/step - loss: 22.3556 - mean_absolute_error: 3.4705 - val_loss: 1963.7660 - val_mean_absolute_error: 43.4972
# Epoch 35/200
# 12/12 [==============================] - 0s 7ms/step - loss: 25.5988 - mean_absolute_error: 3.9341 - val_loss: 162.5183 - val_mean_absolute_error: 12.4088
# Epoch 36/200
# 12/12 [==============================] - 0s 7ms/step - loss: 22.1778 - mean_absolute_error: 3.7762 - val_loss: 106.2184 - val_mean_absolute_error: 9.4722
# Epoch 37/200
# 12/12 [==============================] - 0s 6ms/step - loss: 15.2035 - mean_absolute_error: 3.1077 - val_loss: 29.4031 - val_mean_absolute_error: 4.8630
# Epoch 38/200
# 12/12 [==============================] - 0s 7ms/step - loss: 13.8401 - mean_absolute_error: 2.8650 - val_loss: 114.6264 - val_mean_absolute_error: 10.4628
# Epoch 39/200
# 12/12 [==============================] - 0s 7ms/step - loss: 12.4237 - mean_absolute_error: 2.7647 - val_loss: 213.0384 - val_mean_absolute_error: 14.2663
# Epoch 40/200
# 12/12 [==============================] - 0s 8ms/step - loss: 20.1733 - mean_absolute_error: 3.6015 - val_loss: 75.8870 - val_mean_absolute_error: 8.2218
# Epoch 41/200
# 12/12 [==============================] - 0s 7ms/step - loss: 17.1262 - mean_absolute_error: 3.5203 - val_loss: 39.6230 - val_mean_absolute_error: 5.8678
# Epoch 42/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.4502 - mean_absolute_error: 2.2439 - val_loss: 21.8494 - val_mean_absolute_error: 4.1660
# Epoch 43/200
# 12/12 [==============================] - 0s 6ms/step - loss: 14.5652 - mean_absolute_error: 3.0316 - val_loss: 152.2676 - val_mean_absolute_error: 12.1458
# Epoch 44/200
# 12/12 [==============================] - 0s 6ms/step - loss: 27.3105 - mean_absolute_error: 4.2333 - val_loss: 103.9693 - val_mean_absolute_error: 9.5567
# Epoch 45/200
# 12/12 [==============================] - 0s 8ms/step - loss: 16.3827 - mean_absolute_error: 3.2257 - val_loss: 37.3005 - val_mean_absolute_error: 5.1027
# Epoch 46/200
# 12/12 [==============================] - 0s 6ms/step - loss: 10.0519 - mean_absolute_error: 2.2667 - val_loss: 153.7896 - val_mean_absolute_error: 11.8616
# Epoch 47/200
# 12/12 [==============================] - 0s 7ms/step - loss: 21.7117 - mean_absolute_error: 3.7254 - val_loss: 355.0063 - val_mean_absolute_error: 18.3722
# Epoch 48/200
# 12/12 [==============================] - 0s 6ms/step - loss: 16.2995 - mean_absolute_error: 3.1470 - val_loss: 7.1392 - val_mean_absolute_error: 2.1742
# Epoch 49/200
# 12/12 [==============================] - 0s 6ms/step - loss: 15.8378 - mean_absolute_error: 3.1070 - val_loss: 171.3120 - val_mean_absolute_error: 12.4220
# Epoch 50/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.6561 - mean_absolute_error: 2.0732 - val_loss: 224.4675 - val_mean_absolute_error: 13.9416
# Epoch 51/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.7525 - mean_absolute_error: 2.5039 - val_loss: 296.7943 - val_mean_absolute_error: 15.7098
# Epoch 52/200
# 12/12 [==============================] - 0s 8ms/step - loss: 7.1907 - mean_absolute_error: 1.9244 - val_loss: 92.3071 - val_mean_absolute_error: 8.2575
# Epoch 53/200
# 12/12 [==============================] - 0s 7ms/step - loss: 20.4761 - mean_absolute_error: 3.8479 - val_loss: 19.9008 - val_mean_absolute_error: 3.3221
# Epoch 54/200
# 12/12 [==============================] - 0s 7ms/step - loss: 52.3158 - mean_absolute_error: 5.5169 - val_loss: 28.1782 - val_mean_absolute_error: 4.2886
# Epoch 55/200
# 12/12 [==============================] - 0s 6ms/step - loss: 11.4537 - mean_absolute_error: 2.6369 - val_loss: 26.2090 - val_mean_absolute_error: 4.7936
# Epoch 56/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.4407 - mean_absolute_error: 2.7703 - val_loss: 17.5571 - val_mean_absolute_error: 3.6783
# Epoch 57/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.4526 - mean_absolute_error: 2.5341 - val_loss: 139.0955 - val_mean_absolute_error: 11.2751
# Epoch 58/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.3574 - mean_absolute_error: 2.2838 - val_loss: 227.9235 - val_mean_absolute_error: 14.9826
# Epoch 59/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.3257 - mean_absolute_error: 2.5624 - val_loss: 173.8527 - val_mean_absolute_error: 13.0555
# Epoch 60/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.5459 - mean_absolute_error: 2.4650 - val_loss: 13.9391 - val_mean_absolute_error: 3.1953
# Epoch 61/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.8997 - mean_absolute_error: 2.0745 - val_loss: 35.5820 - val_mean_absolute_error: 4.9515
# Epoch 62/200
# 12/12 [==============================] - 0s 9ms/step - loss: 10.6940 - mean_absolute_error: 2.5415 - val_loss: 470.5652 - val_mean_absolute_error: 21.5577
# Epoch 63/200
# 12/12 [==============================] - 0s 7ms/step - loss: 17.9472 - mean_absolute_error: 3.0574 - val_loss: 268.4729 - val_mean_absolute_error: 15.9764
# Epoch 64/200
# 12/12 [==============================] - 0s 8ms/step - loss: 10.5835 - mean_absolute_error: 2.6245 - val_loss: 12.4762 - val_mean_absolute_error: 2.9706
# Epoch 65/200
# 12/12 [==============================] - 0s 7ms/step - loss: 17.6922 - mean_absolute_error: 3.2805 - val_loss: 76.8751 - val_mean_absolute_error: 8.2349
# Epoch 66/200
# 12/12 [==============================] - 0s 7ms/step - loss: 17.0273 - mean_absolute_error: 3.3807 - val_loss: 18.0257 - val_mean_absolute_error: 3.8642
# Epoch 67/200
# 12/12 [==============================] - 0s 7ms/step - loss: 14.1802 - mean_absolute_error: 3.2694 - val_loss: 36.8998 - val_mean_absolute_error: 5.0013
# Epoch 68/200
# 12/12 [==============================] - 0s 8ms/step - loss: 5.8527 - mean_absolute_error: 1.8494 - val_loss: 67.7565 - val_mean_absolute_error: 6.8276
# Epoch 69/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.7368 - mean_absolute_error: 1.9962 - val_loss: 62.4093 - val_mean_absolute_error: 6.3570
# Epoch 70/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.2684 - mean_absolute_error: 2.3091 - val_loss: 83.2841 - val_mean_absolute_error: 7.5838
# Epoch 71/200
# 12/12 [==============================] - 0s 7ms/step - loss: 10.6334 - mean_absolute_error: 2.4442 - val_loss: 28.3869 - val_mean_absolute_error: 4.4262
# Epoch 72/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.8833 - mean_absolute_error: 2.0141 - val_loss: 174.5253 - val_mean_absolute_error: 11.9157
# Epoch 73/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.7224 - mean_absolute_error: 1.7947 - val_loss: 266.4972 - val_mean_absolute_error: 15.7891
# Epoch 74/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1444 - mean_absolute_error: 2.0868 - val_loss: 375.4869 - val_mean_absolute_error: 18.9506
# Epoch 75/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.3701 - mean_absolute_error: 2.1905 - val_loss: 266.3784 - val_mean_absolute_error: 15.4368
# Epoch 76/200
# 12/12 [==============================] - 0s 6ms/step - loss: 5.7470 - mean_absolute_error: 1.6269 - val_loss: 186.9104 - val_mean_absolute_error: 12.2161
# Epoch 77/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.8167 - mean_absolute_error: 1.9291 - val_loss: 344.6868 - val_mean_absolute_error: 18.3181
# Epoch 78/200
# 12/12 [==============================] - 0s 6ms/step - loss: 8.0523 - mean_absolute_error: 2.2429 - val_loss: 361.6301 - val_mean_absolute_error: 18.5964
# Epoch 79/200
# 12/12 [==============================] - 0s 10ms/step - loss: 11.7287 - mean_absolute_error: 2.8142 - val_loss: 62.5793 - val_mean_absolute_error: 6.7179
# Epoch 80/200
# 12/12 [==============================] - 0s 8ms/step - loss: 11.4602 - mean_absolute_error: 2.4044 - val_loss: 159.5445 - val_mean_absolute_error: 12.3282
# Epoch 81/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.8630 - mean_absolute_error: 2.3106 - val_loss: 130.6542 - val_mean_absolute_error: 9.8042
# Epoch 82/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.1667 - mean_absolute_error: 1.7554 - val_loss: 145.0887 - val_mean_absolute_error: 11.2342
# Epoch 83/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.5722 - mean_absolute_error: 1.9508 - val_loss: 146.2559 - val_mean_absolute_error: 10.7250
# Epoch 84/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.1807 - mean_absolute_error: 1.9363 - val_loss: 194.7461 - val_mean_absolute_error: 13.6335
# Epoch 85/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.7051 - mean_absolute_error: 1.7895 - val_loss: 292.0107 - val_mean_absolute_error: 16.3606
# Epoch 86/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.8412 - mean_absolute_error: 2.2097 - val_loss: 360.0294 - val_mean_absolute_error: 18.5488
# Epoch 87/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.3245 - mean_absolute_error: 2.4162 - val_loss: 332.6208 - val_mean_absolute_error: 17.9515
# Epoch 88/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1860 - mean_absolute_error: 2.0723 - val_loss: 128.5888 - val_mean_absolute_error: 10.0421
# Epoch 89/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.1560 - mean_absolute_error: 2.3202 - val_loss: 166.8823 - val_mean_absolute_error: 11.6333
# Epoch 90/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.4308 - mean_absolute_error: 1.8243 - val_loss: 373.3737 - val_mean_absolute_error: 18.9454
# Epoch 91/200
# 12/12 [==============================] - 0s 8ms/step - loss: 13.1582 - mean_absolute_error: 2.9575 - val_loss: 327.0172 - val_mean_absolute_error: 17.4665
# Epoch 92/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1852 - mean_absolute_error: 2.1031 - val_loss: 196.7234 - val_mean_absolute_error: 13.3648
# Epoch 93/200
# 12/12 [==============================] - 0s 6ms/step - loss: 7.3426 - mean_absolute_error: 2.0939 - val_loss: 243.6439 - val_mean_absolute_error: 15.0711
# Epoch 94/200
# 12/12 [==============================] - 0s 6ms/step - loss: 5.7181 - mean_absolute_error: 1.7920 - val_loss: 210.4637 - val_mean_absolute_error: 13.6095
# Epoch 95/200
# 12/12 [==============================] - 0s 7ms/step - loss: 4.1617 - mean_absolute_error: 1.4886 - val_loss: 95.4095 - val_mean_absolute_error: 8.3576
# Epoch 96/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.9106 - mean_absolute_error: 2.5709 - val_loss: 254.2612 - val_mean_absolute_error: 15.4641
# Epoch 97/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.6352 - mean_absolute_error: 1.6422 - val_loss: 155.0008 - val_mean_absolute_error: 10.9365
# Epoch 98/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.5446 - mean_absolute_error: 1.9410 - val_loss: 190.8180 - val_mean_absolute_error: 12.9669
# Epoch 99/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.2386 - mean_absolute_error: 1.9692 - val_loss: 161.4751 - val_mean_absolute_error: 11.8867
# Epoch 100/200
# 12/12 [==============================] - 0s 8ms/step - loss: 5.4212 - mean_absolute_error: 1.7112 - val_loss: 43.4919 - val_mean_absolute_error: 5.4736
# Epoch 101/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6249 - mean_absolute_error: 2.5115 - val_loss: 244.7614 - val_mean_absolute_error: 15.2005
# Epoch 102/200
# 12/12 [==============================] - 0s 8ms/step - loss: 6.3792 - mean_absolute_error: 1.8529 - val_loss: 242.7326 - val_mean_absolute_error: 14.8309
# Epoch 103/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.2026 - mean_absolute_error: 1.7151 - val_loss: 318.9119 - val_mean_absolute_error: 17.2344
# Epoch 104/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.2905 - mean_absolute_error: 1.9822 - val_loss: 387.7938 - val_mean_absolute_error: 19.4075
# Epoch 105/200
# 12/12 [==============================] - 0s 7ms/step - loss: 10.9075 - mean_absolute_error: 2.4636 - val_loss: 329.4138 - val_mean_absolute_error: 17.6185
# Epoch 106/200
# 12/12 [==============================] - 0s 7ms/step - loss: 3.3891 - mean_absolute_error: 1.3356 - val_loss: 120.9585 - val_mean_absolute_error: 9.8866
# Epoch 107/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.1313 - mean_absolute_error: 2.6993 - val_loss: 49.1924 - val_mean_absolute_error: 5.7342
# Epoch 108/200
# 12/12 [==============================] - 0s 8ms/step - loss: 10.5526 - mean_absolute_error: 2.5312 - val_loss: 97.9056 - val_mean_absolute_error: 9.0267
# Epoch 109/200
# 12/12 [==============================] - 0s 8ms/step - loss: 7.3124 - mean_absolute_error: 2.0455 - val_loss: 120.5264 - val_mean_absolute_error: 9.9011
# Epoch 110/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.0822 - mean_absolute_error: 1.8743 - val_loss: 236.5071 - val_mean_absolute_error: 14.7666
# Epoch 111/200
# 12/12 [==============================] - 0s 8ms/step - loss: 6.3530 - mean_absolute_error: 1.8063 - val_loss: 309.0081 - val_mean_absolute_error: 17.1935
# Epoch 112/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.2341 - mean_absolute_error: 1.8757 - val_loss: 193.8598 - val_mean_absolute_error: 13.1285
# Epoch 113/200
# 12/12 [==============================] - 0s 8ms/step - loss: 4.3799 - mean_absolute_error: 1.5209 - val_loss: 147.6946 - val_mean_absolute_error: 11.0410
# Epoch 114/200
# 12/12 [==============================] - 0s 7ms/step - loss: 4.9879 - mean_absolute_error: 1.7026 - val_loss: 245.7404 - val_mean_absolute_error: 15.1595
# Epoch 115/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.7886 - mean_absolute_error: 1.8890 - val_loss: 258.8828 - val_mean_absolute_error: 15.3355
# Epoch 116/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.9801 - mean_absolute_error: 1.9344 - val_loss: 145.9114 - val_mean_absolute_error: 11.2883
# Epoch 117/200
# 12/12 [==============================] - 0s 8ms/step - loss: 5.2883 - mean_absolute_error: 1.7713 - val_loss: 236.5716 - val_mean_absolute_error: 14.7614
# Epoch 118/200
# 12/12 [==============================] - 0s 7ms/step - loss: 15.7205 - mean_absolute_error: 2.9937 - val_loss: 4.9998 - val_mean_absolute_error: 1.9423
# Epoch 119/200
# 12/12 [==============================] - 0s 7ms/step - loss: 13.9692 - mean_absolute_error: 2.6947 - val_loss: 126.0047 - val_mean_absolute_error: 10.9451
# Epoch 120/200
# 12/12 [==============================] - 0s 9ms/step - loss: 7.9461 - mean_absolute_error: 2.2459 - val_loss: 106.3424 - val_mean_absolute_error: 9.3391
# Epoch 121/200
# 12/12 [==============================] - 0s 8ms/step - loss: 8.5896 - mean_absolute_error: 2.3251 - val_loss: 354.7527 - val_mean_absolute_error: 18.1106
# Epoch 122/200
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9406 - mean_absolute_error: 2.1428 - val_loss: 168.1065 - val_mean_absolute_error: 12.7266
# Epoch 123/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.8451 - mean_absolute_error: 1.8672 - val_loss: 286.5889 - val_mean_absolute_error: 16.6574
# Epoch 124/200
# 12/12 [==============================] - 0s 8ms/step - loss: 7.8288 - mean_absolute_error: 2.2179 - val_loss: 236.5868 - val_mean_absolute_error: 14.7525
# Epoch 125/200
# 12/12 [==============================] - 0s 8ms/step - loss: 4.5341 - mean_absolute_error: 1.5978 - val_loss: 227.8437 - val_mean_absolute_error: 14.5680
# Epoch 126/200
# 12/12 [==============================] - 0s 7ms/step - loss: 4.1375 - mean_absolute_error: 1.4503 - val_loss: 173.8814 - val_mean_absolute_error: 12.3363
# Epoch 127/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.4869 - mean_absolute_error: 1.6414 - val_loss: 156.8950 - val_mean_absolute_error: 11.5469
# Epoch 128/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.6595 - mean_absolute_error: 1.5624 - val_loss: 217.7759 - val_mean_absolute_error: 14.4069
# Epoch 129/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.7729 - mean_absolute_error: 1.7459 - val_loss: 323.4191 - val_mean_absolute_error: 17.6854
# Epoch 130/200
# 12/12 [==============================] - 0s 7ms/step - loss: 4.1705 - mean_absolute_error: 1.6231 - val_loss: 293.7621 - val_mean_absolute_error: 16.7073
# Epoch 131/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.5992 - mean_absolute_error: 1.7352 - val_loss: 310.2612 - val_mean_absolute_error: 17.4626
# Epoch 132/200
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8081 - mean_absolute_error: 1.9936 - val_loss: 164.3661 - val_mean_absolute_error: 11.8782
# Epoch 133/200
# 12/12 [==============================] - 0s 7ms/step - loss: 5.3027 - mean_absolute_error: 1.6753 - val_loss: 191.8895 - val_mean_absolute_error: 13.1510
# Epoch 134/200
# 12/12 [==============================] - 0s 7ms/step - loss: 4.5744 - mean_absolute_error: 1.5459 - val_loss: 189.5696 - val_mean_absolute_error: 13.3433
# Epoch 135/200
# 12/12 [==============================] - 0s 8ms/step - loss: 3.2613 - mean_absolute_error: 1.2563 - val_loss: 161.9707 - val_mean_absolute_error: 12.1187
# Epoch 136/200
# 12/12 [==============================] - 0s 8ms/step - loss: 7.4285 - mean_absolute_error: 2.0127 - val_loss: 256.8540 - val_mean_absolute_error: 15.6573
# Epoch 137/200
# 12/12 [==============================] - 0s 7ms/step - loss: 4.5142 - mean_absolute_error: 1.5227 - val_loss: 200.6390 - val_mean_absolute_error: 13.5834
# Epoch 138/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.2377 - mean_absolute_error: 1.8790 - val_loss: 143.7588 - val_mean_absolute_error: 11.2236
# Epoch 139/200
# 12/12 [==============================] - 0s 8ms/step - loss: 4.4339 - mean_absolute_error: 1.6573 - val_loss: 25.1774 - val_mean_absolute_error: 4.4289
# Epoch 140/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.4811 - mean_absolute_error: 2.3426 - val_loss: 67.6446 - val_mean_absolute_error: 7.2802
# Epoch 141/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.6667 - mean_absolute_error: 2.2663 - val_loss: 135.8364 - val_mean_absolute_error: 10.2634
# Epoch 142/200
# 12/12 [==============================] - 0s 8ms/step - loss: 9.5612 - mean_absolute_error: 2.2640 - val_loss: 465.8136 - val_mean_absolute_error: 21.4794
# Epoch 143/200
# 12/12 [==============================] - 0s 6ms/step - loss: 148.0590 - mean_absolute_error: 8.7688 - val_loss: 19.5236 - val_mean_absolute_error: 3.9887
# Epoch 144/200
# 12/12 [==============================] - 0s 7ms/step - loss: 37.1349 - mean_absolute_error: 5.2494 - val_loss: 10.4406 - val_mean_absolute_error: 2.4792
# Epoch 145/200
# 12/12 [==============================] - 0s 7ms/step - loss: 46.3386 - mean_absolute_error: 5.3510 - val_loss: 25.8218 - val_mean_absolute_error: 4.6563
# Epoch 146/200
# 12/12 [==============================] - 0s 7ms/step - loss: 27.3053 - mean_absolute_error: 3.9168 - val_loss: 18.5828 - val_mean_absolute_error: 3.9681
# Epoch 147/200
# 12/12 [==============================] - 0s 8ms/step - loss: 31.1554 - mean_absolute_error: 4.6920 - val_loss: 118.2259 - val_mean_absolute_error: 10.6763
# Epoch 148/200
# 12/12 [==============================] - 0s 7ms/step - loss: 35.1112 - mean_absolute_error: 4.6363 - val_loss: 80.0435 - val_mean_absolute_error: 8.7037
# Epoch 149/200
# 12/12 [==============================] - 0s 6ms/step - loss: 28.4900 - mean_absolute_error: 4.2684 - val_loss: 26.6237 - val_mean_absolute_error: 4.7918
# Epoch 150/200
# 12/12 [==============================] - 0s 7ms/step - loss: 18.8334 - mean_absolute_error: 3.2482 - val_loss: 18.2233 - val_mean_absolute_error: 3.9157
# Epoch 151/200
# 12/12 [==============================] - 0s 7ms/step - loss: 20.6206 - mean_absolute_error: 3.4923 - val_loss: 42.1851 - val_mean_absolute_error: 6.1834
# Epoch 152/200
# 12/12 [==============================] - 0s 7ms/step - loss: 19.6874 - mean_absolute_error: 3.2261 - val_loss: 24.7311 - val_mean_absolute_error: 4.6349
# Epoch 153/200
# 12/12 [==============================] - 0s 7ms/step - loss: 13.7723 - mean_absolute_error: 3.0437 - val_loss: 61.1547 - val_mean_absolute_error: 7.6031
# Epoch 154/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.8047 - mean_absolute_error: 2.3902 - val_loss: 38.9335 - val_mean_absolute_error: 5.9665
# Epoch 155/200
# 12/12 [==============================] - 0s 10ms/step - loss: 11.3138 - mean_absolute_error: 2.5750 - val_loss: 36.4881 - val_mean_absolute_error: 5.7710
# Epoch 156/200
# 12/12 [==============================] - 0s 7ms/step - loss: 14.8057 - mean_absolute_error: 3.0983 - val_loss: 44.4804 - val_mean_absolute_error: 6.4293
# Epoch 157/200
# 12/12 [==============================] - 0s 7ms/step - loss: 17.6881 - mean_absolute_error: 3.4118 - val_loss: 32.2053 - val_mean_absolute_error: 5.3949
# Epoch 158/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.4262 - mean_absolute_error: 2.7502 - val_loss: 53.1394 - val_mean_absolute_error: 7.0981
# Epoch 159/200
# 12/12 [==============================] - 0s 7ms/step - loss: 12.3000 - mean_absolute_error: 2.8057 - val_loss: 87.2738 - val_mean_absolute_error: 9.2011
# Epoch 160/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.5542 - mean_absolute_error: 2.6865 - val_loss: 41.2489 - val_mean_absolute_error: 6.2082
# Epoch 161/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.9522 - mean_absolute_error: 2.7105 - val_loss: 43.8937 - val_mean_absolute_error: 6.4130
# Epoch 162/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.5096 - mean_absolute_error: 2.2281 - val_loss: 50.1417 - val_mean_absolute_error: 6.8910
# Epoch 163/200
# 12/12 [==============================] - 0s 6ms/step - loss: 12.8484 - mean_absolute_error: 2.8707 - val_loss: 65.3598 - val_mean_absolute_error: 7.9246
# Epoch 164/200
# 12/12 [==============================] - 0s 6ms/step - loss: 10.5728 - mean_absolute_error: 2.5142 - val_loss: 58.8387 - val_mean_absolute_error: 7.5000
# Epoch 165/200
# 12/12 [==============================] - 0s 6ms/step - loss: 11.4253 - mean_absolute_error: 2.5664 - val_loss: 75.6201 - val_mean_absolute_error: 8.5480
# Epoch 166/200
# 12/12 [==============================] - 0s 7ms/step - loss: 10.5625 - mean_absolute_error: 2.5693 - val_loss: 13.4971 - val_mean_absolute_error: 3.3491
# Epoch 167/200
# 12/12 [==============================] - 0s 7ms/step - loss: 13.5882 - mean_absolute_error: 2.8438 - val_loss: 70.2150 - val_mean_absolute_error: 8.2275
# Epoch 168/200
# 12/12 [==============================] - 0s 6ms/step - loss: 13.3541 - mean_absolute_error: 2.9307 - val_loss: 96.1996 - val_mean_absolute_error: 9.6693
# Epoch 169/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.5106 - mean_absolute_error: 2.0311 - val_loss: 36.1751 - val_mean_absolute_error: 5.7966
# Epoch 170/200
# 12/12 [==============================] - 0s 6ms/step - loss: 8.8799 - mean_absolute_error: 2.3222 - val_loss: 21.1356 - val_mean_absolute_error: 4.2982
# Epoch 171/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.9526 - mean_absolute_error: 2.2801 - val_loss: 36.6871 - val_mean_absolute_error: 5.8425
# Epoch 172/200
# 12/12 [==============================] - 0s 6ms/step - loss: 10.8818 - mean_absolute_error: 2.6323 - val_loss: 151.9512 - val_mean_absolute_error: 12.2113
# Epoch 173/200
# 12/12 [==============================] - 0s 7ms/step - loss: 18.6167 - mean_absolute_error: 3.3509 - val_loss: 27.1035 - val_mean_absolute_error: 4.8215
# Epoch 174/200
# 12/12 [==============================] - 0s 7ms/step - loss: 13.1009 - mean_absolute_error: 2.8741 - val_loss: 55.9883 - val_mean_absolute_error: 7.3099
# Epoch 175/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.8116 - mean_absolute_error: 2.1541 - val_loss: 10.4202 - val_mean_absolute_error: 2.9135
# Epoch 176/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.0872 - mean_absolute_error: 2.4339 - val_loss: 5.9619 - val_mean_absolute_error: 2.1683
# Epoch 177/200
# 12/12 [==============================] - 0s 7ms/step - loss: 16.2084 - mean_absolute_error: 3.4717 - val_loss: 5.3749 - val_mean_absolute_error: 2.0500
# Epoch 178/200
# 12/12 [==============================] - 0s 8ms/step - loss: 13.8505 - mean_absolute_error: 3.0109 - val_loss: 11.4549 - val_mean_absolute_error: 3.0655
# Epoch 179/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6886 - mean_absolute_error: 2.3799 - val_loss: 12.0069 - val_mean_absolute_error: 3.1444
# Epoch 180/200
# 12/12 [==============================] - 0s 9ms/step - loss: 15.7114 - mean_absolute_error: 3.2411 - val_loss: 20.7590 - val_mean_absolute_error: 4.2440
# Epoch 181/200
# 12/12 [==============================] - 0s 8ms/step - loss: 9.2962 - mean_absolute_error: 2.2723 - val_loss: 44.4066 - val_mean_absolute_error: 6.4715
# Epoch 182/200
# 12/12 [==============================] - 0s 6ms/step - loss: 10.1145 - mean_absolute_error: 2.4281 - val_loss: 38.3682 - val_mean_absolute_error: 5.9891
# Epoch 183/200
# 12/12 [==============================] - 0s 6ms/step - loss: 13.8543 - mean_absolute_error: 2.9605 - val_loss: 91.3709 - val_mean_absolute_error: 9.4202
# Epoch 184/200
# 12/12 [==============================] - 0s 7ms/step - loss: 15.4182 - mean_absolute_error: 2.9310 - val_loss: 42.4988 - val_mean_absolute_error: 6.3264
# Epoch 185/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.6018 - mean_absolute_error: 1.9022 - val_loss: 51.6929 - val_mean_absolute_error: 7.0208
# Epoch 186/200
# 12/12 [==============================] - 0s 6ms/step - loss: 11.2696 - mean_absolute_error: 2.4999 - val_loss: 118.4215 - val_mean_absolute_error: 10.7654
# Epoch 187/200
# 12/12 [==============================] - 0s 7ms/step - loss: 13.9642 - mean_absolute_error: 2.9307 - val_loss: 82.5451 - val_mean_absolute_error: 8.9311
# Epoch 188/200
# 12/12 [==============================] - 0s 7ms/step - loss: 14.2822 - mean_absolute_error: 2.9258 - val_loss: 28.0573 - val_mean_absolute_error: 4.9970
# Epoch 189/200
# 12/12 [==============================] - 0s 8ms/step - loss: 10.1127 - mean_absolute_error: 2.4540 - val_loss: 10.9056 - val_mean_absolute_error: 2.9779
# Epoch 190/200
# 12/12 [==============================] - 0s 8ms/step - loss: 7.5268 - mean_absolute_error: 2.1122 - val_loss: 29.1477 - val_mean_absolute_error: 5.1647
# Epoch 191/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.2613 - mean_absolute_error: 2.2797 - val_loss: 87.5741 - val_mean_absolute_error: 9.2358
# Epoch 192/200
# 12/12 [==============================] - 0s 7ms/step - loss: 12.2200 - mean_absolute_error: 2.6936 - val_loss: 84.3210 - val_mean_absolute_error: 9.0582
# Epoch 193/200
# 12/12 [==============================] - 0s 7ms/step - loss: 13.2106 - mean_absolute_error: 2.8501 - val_loss: 42.8227 - val_mean_absolute_error: 6.3609
# Epoch 194/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.2498 - mean_absolute_error: 2.3241 - val_loss: 73.6351 - val_mean_absolute_error: 8.4478
# Epoch 195/200
# 12/12 [==============================] - 0s 7ms/step - loss: 11.6087 - mean_absolute_error: 2.4880 - val_loss: 32.9857 - val_mean_absolute_error: 5.5365
# Epoch 196/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.8213 - mean_absolute_error: 2.1326 - val_loss: 60.7156 - val_mean_absolute_error: 7.6462
# Epoch 197/200
# 12/12 [==============================] - 0s 7ms/step - loss: 6.2576 - mean_absolute_error: 1.9688 - val_loss: 24.6296 - val_mean_absolute_error: 4.7214
# Epoch 198/200
# 12/12 [==============================] - 0s 8ms/step - loss: 7.5276 - mean_absolute_error: 1.9793 - val_loss: 57.2070 - val_mean_absolute_error: 7.4146
# Epoch 199/200
# 12/12 [==============================] - 0s 7ms/step - loss: 10.4583 - mean_absolute_error: 2.3433 - val_loss: 39.9989 - val_mean_absolute_error: 6.1441
# Epoch 200/200
# 12/12 [==============================] - 0s 7ms/step - loss: 7.6775 - mean_absolute_error: 1.9733 - val_loss: 27.8926 - val_mean_absolute_error: 5.0655

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print("train MSE", min(history.history['loss']))
print("val MSE", min(history.history['val_loss']))
# Out:
# train MSE 4.678847312927246
# val MSE 4.999792575836182

# %%
print("train MSE", history.history['loss'][-1])
print("val MSE", history.history['val_loss'][-1])
# Out:
# train MSE 7.434532642364502
# val MSE 27.89261245727539

# %%
def prepare_data(timeseries_data, n_features):
	X, y =[],[]
	for i in range(len(timeseries_data)):
		# find the end of this pattern
		end_ix = i + n_features
		# check if we are beyond the sequence
		if end_ix > len(timeseries_data)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = timeseries_data[i:end_ix], timeseries_data[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
X, Y = prepare_data(data, 5)

# %%
Y_pred = model.predict(X)
Y_pred.shape
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 6, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 6, 1), dtype=tf.float32, name='lstm_3_input'), name='lstm_3_input', description="created by layer 'lstm_3_input'"), but it was called on an input with incompatible shape (None, 5, 1).
# (91, 1)

# %%
plt.plot(Y, label='True')
plt.plot(Y_pred,  label='Predict')
plt.legend()
plt.show()

# %%
tf.keras.utils.plot_model(model, to_file='model2.png', show_shapes=True)
